# %% [markdown]
# # OncoMX Biomarker Data Cleaning
#
# ## Issues / TODOs
#
# - Missing `tags`
# - Missing `assessed_entity_type`

# %%
import pandas as pd

# %%
# read in oncomx data tsv using pandas 
raw_df = pd.read_csv('../home/raw_data/oncomx.tsv', sep='\t')
raw_df.head()
# Out:
#   biomarker_id assessed_biomarker_entity_ID assessed_biomarker_entity  \
# 0        A0001                  UPKB:P05231       Interleukin-6 (IL6)
# 1        A0001                  UPKB:P05231       Interleukin-6 (IL6)
# 2        A0001                  UPKB:P05231       Interleukin-6 (IL6)
# 3        A0001                  UPKB:P05231       Interleukin-6 (IL6)
# 4        A0001                  UPKB:P05231       Interleukin-6 (IL6)
#
#              biomarker best_biomarker_role specimen specimen_ID loinc_code  \
# 0  increased IL6 level          prognostic    blood  UN:0000178    26881-3
# 1  increased IL6 level          monitoring    blood  UN:0000178    26881-3
# 2  increased IL6 level          monitoring    blood  UN:0000178    26881-3
# 3  increased IL6 level          monitoring    blood  UN:0000178    26881-3
# 4  increased IL6 level          monitoring    blood  UN:0000178    26881-3
#
#                       condition  condition_ID evidence_source  \
# 0  prostate cancer (DOID:10283)    DOID:10283   PMID:10914713
# 1       COVID-19 (DOID:0080600)  DOID:0080600   PMID:32259560
# 2       COVID-19 (DOID:0080600)  DOID:0080600   PMID:32428990
# 3       COVID-19 (DOID:0080600)  DOID:0080600   PMID:32677844
# 4       COVID-19 (DOID:0080600)  DOID:0080600   PMID:32438331
#
#                                             evidence
# 0  Univariate analysis of all patients demonstrat...
# 1  Serial measurement of circulating IL-6 levels ...
# 2   The decrease of IL-6 was closely related to t...
# 3   Elevated levels of IL-6, D-dimer, CRP, LDH, a...
# 4   Clinical biomarkers for chronic inflammation,...

# %%
new_cols = ['biomarker_id', 'assessed_biomarker_entity_id', 'assessed_biomarker_entity', 'biomarker', 'best_biomarker_role', 'specimen', 'specimen_id', 'loinc_code', 'condition', 'condition_id', 'evidence_source', 'evidence']
# rename raw_df columns with new_cols
raw_df.columns = new_cols
raw_df.head()
# Out:
#   biomarker_id assessed_biomarker_entity_id assessed_biomarker_entity  \
# 0        A0001                  UPKB:P05231       Interleukin-6 (IL6)
# 1        A0001                  UPKB:P05231       Interleukin-6 (IL6)
# 2        A0001                  UPKB:P05231       Interleukin-6 (IL6)
# 3        A0001                  UPKB:P05231       Interleukin-6 (IL6)
# 4        A0001                  UPKB:P05231       Interleukin-6 (IL6)
#
#              biomarker best_biomarker_role specimen specimen_id loinc_code  \
# 0  increased IL6 level          prognostic    blood  UN:0000178    26881-3
# 1  increased IL6 level          monitoring    blood  UN:0000178    26881-3
# 2  increased IL6 level          monitoring    blood  UN:0000178    26881-3
# 3  increased IL6 level          monitoring    blood  UN:0000178    26881-3
# 4  increased IL6 level          monitoring    blood  UN:0000178    26881-3
#
#                       condition  condition_id evidence_source  \
# 0  prostate cancer (DOID:10283)    DOID:10283   PMID:10914713
# 1       COVID-19 (DOID:0080600)  DOID:0080600   PMID:32259560
# 2       COVID-19 (DOID:0080600)  DOID:0080600   PMID:32428990
# 3       COVID-19 (DOID:0080600)  DOID:0080600   PMID:32677844
# 4       COVID-19 (DOID:0080600)  DOID:0080600   PMID:32438331
#
#                                             evidence
# 0  Univariate analysis of all patients demonstrat...
# 1  Serial measurement of circulating IL-6 levels ...
# 2   The decrease of IL-6 was closely related to t...
# 3   Elevated levels of IL-6, D-dimer, CRP, LDH, a...
# 4   Clinical biomarkers for chronic inflammation,...

# %%
# reorder columns
reordered_cols = ['biomarker_id', 'biomarker', 'assessed_biomarker_entity', 'assessed_biomarker_entity_id', 'condition', 'condition_id', 'best_biomarker_role', 'specimen', 'specimen_id', 'loinc_code', 'evidence_source', 'evidence']
raw_df = raw_df[reordered_cols]
raw_df.head()
# Out:
#   biomarker_id            biomarker assessed_biomarker_entity  \
# 0        A0001  increased IL6 level       Interleukin-6 (IL6)
# 1        A0001  increased IL6 level       Interleukin-6 (IL6)
# 2        A0001  increased IL6 level       Interleukin-6 (IL6)
# 3        A0001  increased IL6 level       Interleukin-6 (IL6)
# 4        A0001  increased IL6 level       Interleukin-6 (IL6)
#
#   assessed_biomarker_entity_id                     condition  condition_id  \
# 0                  UPKB:P05231  prostate cancer (DOID:10283)    DOID:10283
# 1                  UPKB:P05231       COVID-19 (DOID:0080600)  DOID:0080600
# 2                  UPKB:P05231       COVID-19 (DOID:0080600)  DOID:0080600
# 3                  UPKB:P05231       COVID-19 (DOID:0080600)  DOID:0080600
# 4                  UPKB:P05231       COVID-19 (DOID:0080600)  DOID:0080600
#
#   best_biomarker_role specimen specimen_id loinc_code evidence_source  \
# 0          prognostic    blood  UN:0000178    26881-3   PMID:10914713
# 1          monitoring    blood  UN:0000178    26881-3   PMID:32259560
# 2          monitoring    blood  UN:0000178    26881-3   PMID:32428990
# 3          monitoring    blood  UN:0000178    26881-3   PMID:32677844
# 4          monitoring    blood  UN:0000178    26881-3   PMID:32438331
#
#                                             evidence
# 0  Univariate analysis of all patients demonstrat...
# 1  Serial measurement of circulating IL-6 levels ...
# 2   The decrease of IL-6 was closely related to t...
# 3   Elevated levels of IL-6, D-dimer, CRP, LDH, a...
# 4   Clinical biomarkers for chronic inflammation,...

# %%
# rename biomarker_id to oncomx_id
raw_df = raw_df.rename(columns={'biomarker_id': 'oncomx_id'})
raw_df.head()
# Out:
#   oncomx_id            biomarker assessed_biomarker_entity  \
# 0     A0001  increased IL6 level       Interleukin-6 (IL6)
# 1     A0001  increased IL6 level       Interleukin-6 (IL6)
# 2     A0001  increased IL6 level       Interleukin-6 (IL6)
# 3     A0001  increased IL6 level       Interleukin-6 (IL6)
# 4     A0001  increased IL6 level       Interleukin-6 (IL6)
#
#   assessed_biomarker_entity_id                     condition  condition_id  \
# 0                  UPKB:P05231  prostate cancer (DOID:10283)    DOID:10283
# 1                  UPKB:P05231       COVID-19 (DOID:0080600)  DOID:0080600
# 2                  UPKB:P05231       COVID-19 (DOID:0080600)  DOID:0080600
# 3                  UPKB:P05231       COVID-19 (DOID:0080600)  DOID:0080600
# 4                  UPKB:P05231       COVID-19 (DOID:0080600)  DOID:0080600
#
#   best_biomarker_role specimen specimen_id loinc_code evidence_source  \
# 0          prognostic    blood  UN:0000178    26881-3   PMID:10914713
# 1          monitoring    blood  UN:0000178    26881-3   PMID:32259560
# 2          monitoring    blood  UN:0000178    26881-3   PMID:32428990
# 3          monitoring    blood  UN:0000178    26881-3   PMID:32677844
# 4          monitoring    blood  UN:0000178    26881-3   PMID:32438331
#
#                                             evidence
# 0  Univariate analysis of all patients demonstrat...
# 1  Serial measurement of circulating IL-6 levels ...
# 2   The decrease of IL-6 was closely related to t...
# 3   Elevated levels of IL-6, D-dimer, CRP, LDH, a...
# 4   Clinical biomarkers for chronic inflammation,...

# %%
# check for null values 
raw_df.isnull().sum()
# Out:
# tmp_id                            0
# oncomx_id                         0
# biomarker                         1
# assessed_biomarker_entity         0
# assessed_biomarker_entity_id     32
# condition                         0
# condition_id                      0
# best_biomarker_role               0
# specimen                          0
# specimen_id                       0
# loinc_code                      435
# evidence_source                   0
# evidence                          0
# dtype: int64

# %%
# drop row where assessed_biomarker_entity_id or biomarker are null
raw_df.dropna(subset=['assessed_biomarker_entity_id', 'biomarker'], inplace=True)
raw_df.isnull().sum()
# Out:
# tmp_id                            0
# oncomx_id                         0
# biomarker                         0
# assessed_biomarker_entity         0
# assessed_biomarker_entity_id      0
# condition                         0
# condition_id                      0
# best_biomarker_role               0
# specimen                          0
# specimen_id                       0
# loinc_code                      412
# evidence_source                   0
# evidence                          0
# dtype: int64

# %%
raw_df.shape
# Out:
# (923, 13)

# %%
# drop all rows where assessed_biomarker_entity_id contains '<a href' 
raw_df = raw_df[~raw_df['assessed_biomarker_entity_id'].str.contains('<a href')]
raw_df.shape
# Out:
# (846, 13)

# %%
# drop all rows where assessed_biomarker_entity_id doesn't contain a ':' 
raw_df = raw_df[raw_df['assessed_biomarker_entity_id'].str.contains(':')]
raw_df.shape
# Out:
# (845, 13)

# %%
# create a new column 'tmp_id' with group numbers based on core fields 
raw_df['tmp_id'] = raw_df.groupby(['biomarker', 'assessed_biomarker_entity_id', 'assessed_biomarker_entity', 'condition']).ngroup()
raw_df.head()
# Out:
#    tmp_id oncomx_id            biomarker assessed_biomarker_entity  \
# 0     307     A0001  increased IL6 level       Interleukin-6 (IL6)
# 1     297     A0001  increased IL6 level       Interleukin-6 (IL6)
# 2     297     A0001  increased IL6 level       Interleukin-6 (IL6)
# 3     297     A0001  increased IL6 level       Interleukin-6 (IL6)
# 4     297     A0001  increased IL6 level       Interleukin-6 (IL6)
#
#   assessed_biomarker_entity_id                     condition  condition_id  \
# 0                  UPKB:P05231  prostate cancer (DOID:10283)    DOID:10283
# 1                  UPKB:P05231       COVID-19 (DOID:0080600)  DOID:0080600
# 2                  UPKB:P05231       COVID-19 (DOID:0080600)  DOID:0080600
# 3                  UPKB:P05231       COVID-19 (DOID:0080600)  DOID:0080600
# 4                  UPKB:P05231       COVID-19 (DOID:0080600)  DOID:0080600
#
#   best_biomarker_role specimen specimen_id loinc_code evidence_source  \
# 0          prognostic    blood  UN:0000178    26881-3   PMID:10914713
# 1          monitoring    blood  UN:0000178    26881-3   PMID:32259560
# 2          monitoring    blood  UN:0000178    26881-3   PMID:32428990
# 3          monitoring    blood  UN:0000178    26881-3   PMID:32677844
# 4          monitoring    blood  UN:0000178    26881-3   PMID:32438331
#
#                                             evidence
# 0  Univariate analysis of all patients demonstrat...
# 1  Serial measurement of circulating IL-6 levels ...
# 2   The decrease of IL-6 was closely related to t...
# 3   Elevated levels of IL-6, D-dimer, CRP, LDH, a...
# 4   Clinical biomarkers for chronic inflammation,...

# %%
raw_df.value_counts('tmp_id')
# Out:
# tmp_id
# 203    27
# 59     15
# 297    15
# 224    13
# 326     8
#        ..
# 183     1
# 181     1
# 180     1
# 179     1
# 197     1
# Name: count, Length: 550, dtype: int64

# %%
# drop oncomx_id column
cleaned_df = raw_df.drop(columns=['oncomx_id'])
cleaned_df
# Out:
#      tmp_id                     biomarker  \
# 0       307           increased IL6 level
# 1       297           increased IL6 level
# 2       297           increased IL6 level
# 3       297           increased IL6 level
# 4       297           increased IL6 level
# ..      ...                           ...
# 943     379      increased N-glycan level
# 944     382      increased N-glycan level
# 947     376      increased N-glycan level
# 954     117  hypermethylated MIR-9-1 gene
# 955     118   hypermethylated RASSF1 gene
#
#                              assessed_biomarker_entity  \
# 0                                  Interleukin-6 (IL6)
# 1                                  Interleukin-6 (IL6)
# 2                                  Interleukin-6 (IL6)
# 3                                  Interleukin-6 (IL6)
# 4                                  Interleukin-6 (IL6)
# ..                                                 ...
# 943                         Man7 high mannose N-glycan
# 944                         Man8 high mannose N-glycan
# 947                                             Neu5Gc
# 954                           miRNA‑9-1 gene (MIR‑9-1)
# 955  Ras association domain-containing protein 1 ge...
#
#     assessed_biomarker_entity_id                     condition  condition_id  \
# 0                    UPKB:P05231  prostate cancer (DOID:10283)    DOID:10283
# 1                    UPKB:P05231       COVID-19 (DOID:0080600)  DOID:0080600
# 2                    UPKB:P05231       COVID-19 (DOID:0080600)  DOID:0080600
# 3                    UPKB:P05231       COVID-19 (DOID:0080600)  DOID:0080600
# 4                    UPKB:P05231       COVID-19 (DOID:0080600)  DOID:0080600
# ..                           ...                           ...           ...
# 943                 GTC:G36059IK     breast cancer (DOID:1612)     DOID:1612
# 944                 GTC:G66676MI     breast cancer (DOID:1612)     DOID:1612
# 947                 GTC:G26366JF     breast cancer (DOID:1612)     DOID:1612
# 954                MRB:MI0000466    ovarian cancer (DOID:2394)     DOID:2394
# 955                  UPKB:Q9NS23  prostate cancer (DOID:10283)    DOID:10283
#
#     best_biomarker_role specimen specimen_id loinc_code evidence_source  \
# 0            prognostic    blood  UN:0000178    26881-3   PMID:10914713
# 1            monitoring    blood  UN:0000178    26881-3   PMID:32259560
# 2            monitoring    blood  UN:0000178    26881-3   PMID:32428990
# 3            monitoring    blood  UN:0000178    26881-3   PMID:32677844
# 4            monitoring    blood  UN:0000178    26881-3   PMID:32438331
# ..                  ...      ...         ...        ...             ...
# 943          diagnostic   tissue  UN:0000479        NaN   PMID:30889355
# 944          diagnostic   tissue  UN:0000479        NaN   PMID:30889355
# 947          monitoring    blood  UN:0000178        NaN   PMID:35346112
# 954          prognostic    ovary  UN:0000992        NA    PMID:29313235
# 955          prognostic    urine  UN:0001088        NaN   PMID:24980613
#
#                                               evidence
# 0    Univariate analysis of all patients demonstrat...
# 1    Serial measurement of circulating IL-6 levels ...
# 2     The decrease of IL-6 was closely related to t...
# 3     Elevated levels of IL-6, D-dimer, CRP, LDH, a...
# 4     Clinical biomarkers for chronic inflammation,...
# ..                                                 ...
# 943  In comparing the N-glycan profiles of healthy ...
# 944  In comparing the N-glycan profiles of healthy ...
# 947  Analysis of sera from breast cancer cases reve...
# 954  ...five microRNA genes (MIR-9-1, MIR-9-3, MIR-...
# 955  Hypermethylation of RASSF1 in cancerous tissue...
#
# [845 rows x 12 columns]

# %%
# write cleaned_df to tsv
cleaned_df.to_csv('../home/results/tables/oncomx.tsv', sep='\t', index=False)
