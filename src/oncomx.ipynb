# %% [markdown]
# # OncoMX Biomarker Data Exploration

# %%
import pandas as pd
import table_cleaning_functions as tcf

# %%
# read in oncomx data tsv using pandas 
df = pd.read_csv('../data/raw_data/tables/oncomx.tsv', sep='\t')
df.head()
# Out:
#    biomarker_id            biomarker assessed_biomarker_entity  \
# 0           307  increased IL6 level       Interleukin-6 (IL6)
# 1           297  increased IL6 level       Interleukin-6 (IL6)
# 2           297  increased IL6 level       Interleukin-6 (IL6)
# 3           297  increased IL6 level       Interleukin-6 (IL6)
# 4           297  increased IL6 level       Interleukin-6 (IL6)
#
#   assessed_biomarker_entity_id assessed_entity_type  \
# 0                  UPKB:P05231              protein
# 1                  UPKB:P05231              protein
# 2                  UPKB:P05231              protein
# 3                  UPKB:P05231              protein
# 4                  UPKB:P05231              protein
#
#                       condition  condition_id best_biomarker_role specimen  \
# 0  prostate cancer (DOID:10283)    DOID:10283          prognostic    blood
# 1       COVID-19 (DOID:0080600)  DOID:0080600          monitoring    blood
# 2       COVID-19 (DOID:0080600)  DOID:0080600          monitoring    blood
# 3       COVID-19 (DOID:0080600)  DOID:0080600          monitoring    blood
# 4       COVID-19 (DOID:0080600)  DOID:0080600          monitoring    blood
#
#   specimen_id loinc_code evidence_source  \
# 0  UN:0000178    26881-3   PMID:10914713
# 1  UN:0000178    26881-3   PMID:32259560
# 2  UN:0000178    26881-3   PMID:32428990
# 3  UN:0000178    26881-3   PMID:32677844
# 4  UN:0000178    26881-3   PMID:32438331
#
#                                             evidence  \
# 0  Univariate analysis of all patients demonstrat...
# 1  Serial measurement of circulating IL-6 levels ...
# 2   The decrease of IL-6 was closely related to t...
# 3   Elevated levels of IL-6, D-dimer, CRP, LDH, a...
# 4   Clinical biomarkers for chronic inflammation,...
#
#                                                  tag
# 0  biomarker; assessed_biomarker_entity; best_bio...
# 1  biomarker; assessed_biomarker_entity; best_bio...
# 2  biomarker; assessed_biomarker_entity; best_bio...
# 3  biomarker; assessed_biomarker_entity; best_bio...
# 4  biomarker; assessed_biomarker_entity; best_bio...

# %%
# check for null values 
df.isnull().sum()
# Out:
# biomarker_id                      0
# biomarker                         0
# assessed_biomarker_entity         0
# assessed_biomarker_entity_id      0
# assessed_entity_type              0
# condition                         0
# condition_id                      0
# best_biomarker_role               0
# specimen                          0
# specimen_id                       0
# loinc_code                      363
# evidence_source                   0
# evidence                          0
# tag                               0
# dtype: int64

# %%
df.shape
# Out:
# (845, 14)

# %%
# clean condition and assessed_biomarker_entity columns 
df['condition'] = tcf.clean_parantheticals(df['condition'])
df['assessed_biomarker_entity'] = tcf.clean_parantheticals(df['assessed_biomarker_entity'])
df.head()
# Out:
#    biomarker_id            biomarker assessed_biomarker_entity  \
# 0           307  increased IL6 level             Interleukin-6
# 1           297  increased IL6 level             Interleukin-6
# 2           297  increased IL6 level             Interleukin-6
# 3           297  increased IL6 level             Interleukin-6
# 4           297  increased IL6 level             Interleukin-6
#
#   assessed_biomarker_entity_id assessed_entity_type        condition  \
# 0                  UPKB:P05231              protein  prostate cancer
# 1                  UPKB:P05231              protein         COVID-19
# 2                  UPKB:P05231              protein         COVID-19
# 3                  UPKB:P05231              protein         COVID-19
# 4                  UPKB:P05231              protein         COVID-19
#
#    condition_id best_biomarker_role specimen specimen_id loinc_code  \
# 0    DOID:10283          prognostic    blood  UN:0000178    26881-3
# 1  DOID:0080600          monitoring    blood  UN:0000178    26881-3
# 2  DOID:0080600          monitoring    blood  UN:0000178    26881-3
# 3  DOID:0080600          monitoring    blood  UN:0000178    26881-3
# 4  DOID:0080600          monitoring    blood  UN:0000178    26881-3
#
#   evidence_source                                           evidence  \
# 0   PMID:10914713  Univariate analysis of all patients demonstrat...
# 1   PMID:32259560  Serial measurement of circulating IL-6 levels ...
# 2   PMID:32428990   The decrease of IL-6 was closely related to t...
# 3   PMID:32677844   Elevated levels of IL-6, D-dimer, CRP, LDH, a...
# 4   PMID:32438331   Clinical biomarkers for chronic inflammation,...
#
#                                                  tag
# 0  biomarker; assessed_biomarker_entity; best_bio...
# 1  biomarker; assessed_biomarker_entity; best_bio...
# 2  biomarker; assessed_biomarker_entity; best_bio...
# 3  biomarker; assessed_biomarker_entity; best_bio...
# 4  biomarker; assessed_biomarker_entity; best_bio...

# %%
# map prefixes in specimen_id and evidence source columns 
df['specimen_id'] = tcf.map_prefixes(df['specimen_id'])
df['evidence_source'] = tcf.map_prefixes(df['evidence_source'])
df.head()
# Out:
#    biomarker_id            biomarker assessed_biomarker_entity  \
# 0           307  increased IL6 level             Interleukin-6
# 1           297  increased IL6 level             Interleukin-6
# 2           297  increased IL6 level             Interleukin-6
# 3           297  increased IL6 level             Interleukin-6
# 4           297  increased IL6 level             Interleukin-6
#
#   assessed_biomarker_entity_id assessed_entity_type        condition  \
# 0                  UPKB:P05231              protein  prostate cancer
# 1                  UPKB:P05231              protein         COVID-19
# 2                  UPKB:P05231              protein         COVID-19
# 3                  UPKB:P05231              protein         COVID-19
# 4                  UPKB:P05231              protein         COVID-19
#
#    condition_id best_biomarker_role specimen     specimen_id loinc_code  \
# 0    DOID:10283          prognostic    blood  UBERON:0000178    26881-3
# 1  DOID:0080600          monitoring    blood  UBERON:0000178    26881-3
# 2  DOID:0080600          monitoring    blood  UBERON:0000178    26881-3
# 3  DOID:0080600          monitoring    blood  UBERON:0000178    26881-3
# 4  DOID:0080600          monitoring    blood  UBERON:0000178    26881-3
#
#    evidence_source                                           evidence  \
# 0  PubMed:10914713  Univariate analysis of all patients demonstrat...
# 1  PubMed:32259560  Serial measurement of circulating IL-6 levels ...
# 2  PubMed:32428990   The decrease of IL-6 was closely related to t...
# 3  PubMed:32677844   Elevated levels of IL-6, D-dimer, CRP, LDH, a...
# 4  PubMed:32438331   Clinical biomarkers for chronic inflammation,...
#
#                                                  tag
# 0  biomarker; assessed_biomarker_entity; best_bio...
# 1  biomarker; assessed_biomarker_entity; best_bio...
# 2  biomarker; assessed_biomarker_entity; best_bio...
# 3  biomarker; assessed_biomarker_entity; best_bio...
# 4  biomarker; assessed_biomarker_entity; best_bio...

# %%
# strip whitespace from evidence column 
df['evidence'] = tcf.strip_values(df['evidence'])
df.head()
# Out:
#    biomarker_id            biomarker assessed_biomarker_entity  \
# 0           307  increased IL6 level             Interleukin-6
# 1           297  increased IL6 level             Interleukin-6
# 2           297  increased IL6 level             Interleukin-6
# 3           297  increased IL6 level             Interleukin-6
# 4           297  increased IL6 level             Interleukin-6
#
#   assessed_biomarker_entity_id assessed_entity_type        condition  \
# 0                  UPKB:P05231              protein  prostate cancer
# 1                  UPKB:P05231              protein         COVID-19
# 2                  UPKB:P05231              protein         COVID-19
# 3                  UPKB:P05231              protein         COVID-19
# 4                  UPKB:P05231              protein         COVID-19
#
#    condition_id best_biomarker_role specimen     specimen_id loinc_code  \
# 0    DOID:10283          prognostic    blood  UBERON:0000178    26881-3
# 1  DOID:0080600          monitoring    blood  UBERON:0000178    26881-3
# 2  DOID:0080600          monitoring    blood  UBERON:0000178    26881-3
# 3  DOID:0080600          monitoring    blood  UBERON:0000178    26881-3
# 4  DOID:0080600          monitoring    blood  UBERON:0000178    26881-3
#
#    evidence_source                                           evidence  \
# 0  PubMed:10914713  Univariate analysis of all patients demonstrat...
# 1  PubMed:32259560  Serial measurement of circulating IL-6 levels ...
# 2  PubMed:32428990  The decrease of IL-6 was closely related to tr...
# 3  PubMed:32677844  Elevated levels of IL-6, D-dimer, CRP, LDH, an...
# 4  PubMed:32438331  Clinical biomarkers for chronic inflammation, ...
#
#                                                  tag
# 0  biomarker; assessed_biomarker_entity; best_bio...
# 1  biomarker; assessed_biomarker_entity; best_bio...
# 2  biomarker; assessed_biomarker_entity; best_bio...
# 3  biomarker; assessed_biomarker_entity; best_bio...
# 4  biomarker; assessed_biomarker_entity; best_bio...

# %%
# write tsv 
df.to_csv('../data/results/tables/oncomx.tsv', sep='\t', index=False)

# %%
# OLD 
# create a new column 'tmp_id' with group numbers based on core fields 
df['tmp_id'] = df.groupby(['biomarker', 'assessed_biomarker_entity_id', 'assessed_biomarker_entity', 'condition']).ngroup()
df.head()
# Out:
#    tmp_id oncomx_id            biomarker assessed_biomarker_entity  \
# 0     307     A0001  increased IL6 level       Interleukin-6 (IL6)
# 1     297     A0001  increased IL6 level       Interleukin-6 (IL6)
# 2     297     A0001  increased IL6 level       Interleukin-6 (IL6)
# 3     297     A0001  increased IL6 level       Interleukin-6 (IL6)
# 4     297     A0001  increased IL6 level       Interleukin-6 (IL6)
#
#   assessed_biomarker_entity_id                     condition  condition_id  \
# 0                  UPKB:P05231  prostate cancer (DOID:10283)    DOID:10283
# 1                  UPKB:P05231       COVID-19 (DOID:0080600)  DOID:0080600
# 2                  UPKB:P05231       COVID-19 (DOID:0080600)  DOID:0080600
# 3                  UPKB:P05231       COVID-19 (DOID:0080600)  DOID:0080600
# 4                  UPKB:P05231       COVID-19 (DOID:0080600)  DOID:0080600
#
#   best_biomarker_role specimen specimen_id loinc_code evidence_source  \
# 0          prognostic    blood  UN:0000178    26881-3   PMID:10914713
# 1          monitoring    blood  UN:0000178    26881-3   PMID:32259560
# 2          monitoring    blood  UN:0000178    26881-3   PMID:32428990
# 3          monitoring    blood  UN:0000178    26881-3   PMID:32677844
# 4          monitoring    blood  UN:0000178    26881-3   PMID:32438331
#
#                                             evidence
# 0  Univariate analysis of all patients demonstrat...
# 1  Serial measurement of circulating IL-6 levels ...
# 2   The decrease of IL-6 was closely related to t...
# 3   Elevated levels of IL-6, D-dimer, CRP, LDH, a...
# 4   Clinical biomarkers for chronic inflammation,...
