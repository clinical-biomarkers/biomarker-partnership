# %% [markdown]
# # OncoMX Biomarker Data Exploration

# %%
import pandas as pd
import table_cleaning_functions as tcf

# %%
# read in oncomx data tsv using pandas 
df = pd.read_csv('../data/raw_data/tables/oncomx.tsv', sep='\t')
df.head()
# Out:
#   biomarker_id            biomarker assessed_biomarker_entity_ID  \
# 0        A0001  increased IL6 level                  UPKB:P05231
# 1        A0001  increased IL6 level                  UPKB:P05231
# 2        A0001  increased IL6 level                  UPKB:P05231
# 3        A0001  increased IL6 level                  UPKB:P05231
# 4        A0001  increased IL6 level                  UPKB:P05231
#
#   assessed_biomarker_entity assessed_entity_type best_biomarker_role specimen  \
# 0       Interleukin-6 (IL6)              protein          prognostic    blood
# 1       Interleukin-6 (IL6)              protein          monitoring    blood
# 2       Interleukin-6 (IL6)              protein          monitoring    blood
# 3       Interleukin-6 (IL6)              protein          monitoring    blood
# 4       Interleukin-6 (IL6)              protein          monitoring    blood
#
#   specimen_ID loinc_code        condition  condition_ID evidence_source  \
# 0  UN:0000178    26881-3  prostate cancer    DOID:10283   PMID:10914713
# 1  UN:0000178    26881-3         COVID-19  DOID:0080600   PMID:32259560
# 2  UN:0000178    26881-3         COVID-19  DOID:0080600   PMID:32428990
# 3  UN:0000178    26881-3         COVID-19  DOID:0080600   PMID:32677844
# 4  UN:0000178    26881-3         COVID-19  DOID:0080600   PMID:32438331
#
#                                             evidence  \
# 0  Univariate analysis of all patients demonstrat...
# 1  Serial measurement of circulating IL-6 levels ...
# 2   The decrease of IL-6 was closely related to t...
# 3   Elevated levels of IL-6, D-dimer, CRP, LDH, a...
# 4   Clinical biomarkers for chronic inflammation,...
#
#                                                 tags
# 0  biomarker; assessed_biomarker_entity; best_bio...
# 1  biomarker; assessed_biomarker_entity; best_bio...
# 2  biomarker; assessed_biomarker_entity; best_bio...
# 3  biomarker; assessed_biomarker_entity; best_bio...
# 4  biomarker; assessed_biomarker_entity; best_bio...

# %%
# check for null values 
df.isnull().sum()
# Out:
# biomarker_id                      0
# biomarker                         1
# assessed_biomarker_entity_ID     32
# assessed_biomarker_entity         0
# assessed_entity_type              0
# best_biomarker_role               0
# specimen                          0
# specimen_ID                       0
# loinc_code                      435
# condition                         0
# condition_ID                      0
# evidence_source                   0
# evidence                          0
# tags                              0
# dtype: int64

# %%
# rename columns to lowercase 
df.columns = df.columns.str.lower()
df.head()
# Out:
#   biomarker_id            biomarker assessed_biomarker_entity_id  \
# 0        A0001  increased IL6 level                  UPKB:P05231
# 1        A0001  increased IL6 level                  UPKB:P05231
# 2        A0001  increased IL6 level                  UPKB:P05231
# 3        A0001  increased IL6 level                  UPKB:P05231
# 4        A0001  increased IL6 level                  UPKB:P05231
#
#   assessed_biomarker_entity assessed_entity_type best_biomarker_role specimen  \
# 0       Interleukin-6 (IL6)              protein          prognostic    blood
# 1       Interleukin-6 (IL6)              protein          monitoring    blood
# 2       Interleukin-6 (IL6)              protein          monitoring    blood
# 3       Interleukin-6 (IL6)              protein          monitoring    blood
# 4       Interleukin-6 (IL6)              protein          monitoring    blood
#
#   specimen_id loinc_code        condition  condition_id evidence_source  \
# 0  UN:0000178    26881-3  prostate cancer    DOID:10283   PMID:10914713
# 1  UN:0000178    26881-3         COVID-19  DOID:0080600   PMID:32259560
# 2  UN:0000178    26881-3         COVID-19  DOID:0080600   PMID:32428990
# 3  UN:0000178    26881-3         COVID-19  DOID:0080600   PMID:32677844
# 4  UN:0000178    26881-3         COVID-19  DOID:0080600   PMID:32438331
#
#                                             evidence  \
# 0  Univariate analysis of all patients demonstrat...
# 1  Serial measurement of circulating IL-6 levels ...
# 2   The decrease of IL-6 was closely related to t...
# 3   Elevated levels of IL-6, D-dimer, CRP, LDH, a...
# 4   Clinical biomarkers for chronic inflammation,...
#
#                                                 tags
# 0  biomarker; assessed_biomarker_entity; best_bio...
# 1  biomarker; assessed_biomarker_entity; best_bio...
# 2  biomarker; assessed_biomarker_entity; best_bio...
# 3  biomarker; assessed_biomarker_entity; best_bio...
# 4  biomarker; assessed_biomarker_entity; best_bio...

# %%
df.shape
# Out:
# (956, 14)

# %%
# drop rows where assessed_biomarker_entity_id or biomarker are null 
df.dropna(subset = ['assessed_biomarker_entity_id', 'biomarker'], inplace = True)
df.isnull().sum()
# Out:
# biomarker_id                      0
# biomarker                         0
# assessed_biomarker_entity_id      0
# assessed_biomarker_entity         0
# assessed_entity_type              0
# best_biomarker_role               0
# specimen                          0
# specimen_id                       0
# loinc_code                      412
# condition                         0
# condition_id                      0
# evidence_source                   0
# evidence                          0
# tags                              0
# dtype: int64

# %%
df.shape
# Out:
# (923, 14)

# %%
# drop all rows where assessed_biomarker_entity_id contains '<a href' 
df = df[~df['assessed_biomarker_entity_id'].str.contains('<a href')]
df.shape
# Out:
# (846, 14)

# %%
# drop all rows where assessed_biomarker_entity_id doesn't contain a ':' 
df = df[df['assessed_biomarker_entity_id'].str.contains(':')]
df.shape
# Out:
# (845, 14)

# %%
# clean condition and assessed_biomarker_entity columns 
df['condition'] = tcf.clean_parantheticals(df['condition'])
df['assessed_biomarker_entity'] = tcf.clean_parantheticals(df['assessed_biomarker_entity'])
df.head()
# Out:
#   biomarker_id            biomarker assessed_biomarker_entity_id  \
# 0        A0001  increased IL6 level                  UPKB:P05231
# 1        A0001  increased IL6 level                  UPKB:P05231
# 2        A0001  increased IL6 level                  UPKB:P05231
# 3        A0001  increased IL6 level                  UPKB:P05231
# 4        A0001  increased IL6 level                  UPKB:P05231
#
#   assessed_biomarker_entity assessed_entity_type best_biomarker_role specimen  \
# 0             Interleukin-6              protein          prognostic    blood
# 1             Interleukin-6              protein          monitoring    blood
# 2             Interleukin-6              protein          monitoring    blood
# 3             Interleukin-6              protein          monitoring    blood
# 4             Interleukin-6              protein          monitoring    blood
#
#   specimen_id loinc_code        condition  condition_id evidence_source  \
# 0  UN:0000178    26881-3  prostate cancer    DOID:10283   PMID:10914713
# 1  UN:0000178    26881-3         COVID-19  DOID:0080600   PMID:32259560
# 2  UN:0000178    26881-3         COVID-19  DOID:0080600   PMID:32428990
# 3  UN:0000178    26881-3         COVID-19  DOID:0080600   PMID:32677844
# 4  UN:0000178    26881-3         COVID-19  DOID:0080600   PMID:32438331
#
#                                             evidence  \
# 0  Univariate analysis of all patients demonstrat...
# 1  Serial measurement of circulating IL-6 levels ...
# 2   The decrease of IL-6 was closely related to t...
# 3   Elevated levels of IL-6, D-dimer, CRP, LDH, a...
# 4   Clinical biomarkers for chronic inflammation,...
#
#                                                 tags
# 0  biomarker; assessed_biomarker_entity; best_bio...
# 1  biomarker; assessed_biomarker_entity; best_bio...
# 2  biomarker; assessed_biomarker_entity; best_bio...
# 3  biomarker; assessed_biomarker_entity; best_bio...
# 4  biomarker; assessed_biomarker_entity; best_bio...

# %%
# map prefixes in specimen_id and evidence source columns 
df['specimen_id'] = tcf.map_prefixes(df['specimen_id'])
df['evidence_source'] = tcf.map_prefixes(df['evidence_source'])
df.head()
# Out:
#   biomarker_id            biomarker assessed_biomarker_entity_id  \
# 0        A0001  increased IL6 level                  UPKB:P05231
# 1        A0001  increased IL6 level                  UPKB:P05231
# 2        A0001  increased IL6 level                  UPKB:P05231
# 3        A0001  increased IL6 level                  UPKB:P05231
# 4        A0001  increased IL6 level                  UPKB:P05231
#
#   assessed_biomarker_entity assessed_entity_type best_biomarker_role specimen  \
# 0             Interleukin-6              protein          prognostic    blood
# 1             Interleukin-6              protein          monitoring    blood
# 2             Interleukin-6              protein          monitoring    blood
# 3             Interleukin-6              protein          monitoring    blood
# 4             Interleukin-6              protein          monitoring    blood
#
#       specimen_id loinc_code        condition  condition_id  evidence_source  \
# 0  UBERON:0000178    26881-3  prostate cancer    DOID:10283  PubMed:10914713
# 1  UBERON:0000178    26881-3         COVID-19  DOID:0080600  PubMed:32259560
# 2  UBERON:0000178    26881-3         COVID-19  DOID:0080600  PubMed:32428990
# 3  UBERON:0000178    26881-3         COVID-19  DOID:0080600  PubMed:32677844
# 4  UBERON:0000178    26881-3         COVID-19  DOID:0080600  PubMed:32438331
#
#                                             evidence  \
# 0  Univariate analysis of all patients demonstrat...
# 1  Serial measurement of circulating IL-6 levels ...
# 2   The decrease of IL-6 was closely related to t...
# 3   Elevated levels of IL-6, D-dimer, CRP, LDH, a...
# 4   Clinical biomarkers for chronic inflammation,...
#
#                                                 tags
# 0  biomarker; assessed_biomarker_entity; best_bio...
# 1  biomarker; assessed_biomarker_entity; best_bio...
# 2  biomarker; assessed_biomarker_entity; best_bio...
# 3  biomarker; assessed_biomarker_entity; best_bio...
# 4  biomarker; assessed_biomarker_entity; best_bio...

# %%
# strip whitespace from evidence column 
df['evidence'] = tcf.strip_values(df['evidence'])
df.head()
# Out:
#   biomarker_id            biomarker assessed_biomarker_entity_id  \
# 0        A0001  increased IL6 level                  UPKB:P05231
# 1        A0001  increased IL6 level                  UPKB:P05231
# 2        A0001  increased IL6 level                  UPKB:P05231
# 3        A0001  increased IL6 level                  UPKB:P05231
# 4        A0001  increased IL6 level                  UPKB:P05231
#
#   assessed_biomarker_entity assessed_entity_type best_biomarker_role specimen  \
# 0             Interleukin-6              protein          prognostic    blood
# 1             Interleukin-6              protein          monitoring    blood
# 2             Interleukin-6              protein          monitoring    blood
# 3             Interleukin-6              protein          monitoring    blood
# 4             Interleukin-6              protein          monitoring    blood
#
#       specimen_id loinc_code        condition  condition_id  evidence_source  \
# 0  UBERON:0000178    26881-3  prostate cancer    DOID:10283  PubMed:10914713
# 1  UBERON:0000178    26881-3         COVID-19  DOID:0080600  PubMed:32259560
# 2  UBERON:0000178    26881-3         COVID-19  DOID:0080600  PubMed:32428990
# 3  UBERON:0000178    26881-3         COVID-19  DOID:0080600  PubMed:32677844
# 4  UBERON:0000178    26881-3         COVID-19  DOID:0080600  PubMed:32438331
#
#                                             evidence  \
# 0  Univariate analysis of all patients demonstrat...
# 1  Serial measurement of circulating IL-6 levels ...
# 2  The decrease of IL-6 was closely related to tr...
# 3  Elevated levels of IL-6, D-dimer, CRP, LDH, an...
# 4  Clinical biomarkers for chronic inflammation, ...
#
#                                                 tags
# 0  biomarker; assessed_biomarker_entity; best_bio...
# 1  biomarker; assessed_biomarker_entity; best_bio...
# 2  biomarker; assessed_biomarker_entity; best_bio...
# 3  biomarker; assessed_biomarker_entity; best_bio...
# 4  biomarker; assessed_biomarker_entity; best_bio...

# %%
# strip whitespace from all columns
for col in df.columns:
    df[col] = tcf.strip_values(df[col])
df.head()
# Out:
#   biomarker_id            biomarker assessed_biomarker_entity_id  \
# 0        A0001  increased IL6 level                  UPKB:P05231
# 1        A0001  increased IL6 level                  UPKB:P05231
# 2        A0001  increased IL6 level                  UPKB:P05231
# 3        A0001  increased IL6 level                  UPKB:P05231
# 4        A0001  increased IL6 level                  UPKB:P05231
#
#   assessed_biomarker_entity assessed_entity_type best_biomarker_role specimen  \
# 0             Interleukin-6              protein          prognostic    blood
# 1             Interleukin-6              protein          monitoring    blood
# 2             Interleukin-6              protein          monitoring    blood
# 3             Interleukin-6              protein          monitoring    blood
# 4             Interleukin-6              protein          monitoring    blood
#
#       specimen_id loinc_code        condition  condition_id  evidence_source  \
# 0  UBERON:0000178    26881-3  prostate cancer    DOID:10283  PubMed:10914713
# 1  UBERON:0000178    26881-3         COVID-19  DOID:0080600  PubMed:32259560
# 2  UBERON:0000178    26881-3         COVID-19  DOID:0080600  PubMed:32428990
# 3  UBERON:0000178    26881-3         COVID-19  DOID:0080600  PubMed:32677844
# 4  UBERON:0000178    26881-3         COVID-19  DOID:0080600  PubMed:32438331
#
#                                             evidence  \
# 0  Univariate analysis of all patients demonstrat...
# 1  Serial measurement of circulating IL-6 levels ...
# 2  The decrease of IL-6 was closely related to tr...
# 3  Elevated levels of IL-6, D-dimer, CRP, LDH, an...
# 4  Clinical biomarkers for chronic inflammation, ...
#
#                                                 tags
# 0  biomarker; assessed_biomarker_entity; best_bio...
# 1  biomarker; assessed_biomarker_entity; best_bio...
# 2  biomarker; assessed_biomarker_entity; best_bio...
# 3  biomarker; assessed_biomarker_entity; best_bio...
# 4  biomarker; assessed_biomarker_entity; best_bio...

# %%
# create new column 'tmp_id' with group numbers based on core columns and insert as first column
df.insert(0, 'tmp_id', df.groupby(['biomarker', 'assessed_biomarker_entity_id', 'assessed_biomarker_entity', 'condition']).ngroup())
df.head()
# Out:
#    tmp_id biomarker_id            biomarker assessed_biomarker_entity_id  \
# 0     307        A0001  increased IL6 level                  UPKB:P05231
# 1     297        A0001  increased IL6 level                  UPKB:P05231
# 2     297        A0001  increased IL6 level                  UPKB:P05231
# 3     297        A0001  increased IL6 level                  UPKB:P05231
# 4     297        A0001  increased IL6 level                  UPKB:P05231
#
#   assessed_biomarker_entity assessed_entity_type best_biomarker_role specimen  \
# 0             Interleukin-6              protein          prognostic    blood
# 1             Interleukin-6              protein          monitoring    blood
# 2             Interleukin-6              protein          monitoring    blood
# 3             Interleukin-6              protein          monitoring    blood
# 4             Interleukin-6              protein          monitoring    blood
#
#       specimen_id loinc_code        condition  condition_id  evidence_source  \
# 0  UBERON:0000178    26881-3  prostate cancer    DOID:10283  PubMed:10914713
# 1  UBERON:0000178    26881-3         COVID-19  DOID:0080600  PubMed:32259560
# 2  UBERON:0000178    26881-3         COVID-19  DOID:0080600  PubMed:32428990
# 3  UBERON:0000178    26881-3         COVID-19  DOID:0080600  PubMed:32677844
# 4  UBERON:0000178    26881-3         COVID-19  DOID:0080600  PubMed:32438331
#
#                                             evidence  \
# 0  Univariate analysis of all patients demonstrat...
# 1  Serial measurement of circulating IL-6 levels ...
# 2  The decrease of IL-6 was closely related to tr...
# 3  Elevated levels of IL-6, D-dimer, CRP, LDH, an...
# 4  Clinical biomarkers for chronic inflammation, ...
#
#                                                 tags
# 0  biomarker; assessed_biomarker_entity; best_bio...
# 1  biomarker; assessed_biomarker_entity; best_bio...
# 2  biomarker; assessed_biomarker_entity; best_bio...
# 3  biomarker; assessed_biomarker_entity; best_bio...
# 4  biomarker; assessed_biomarker_entity; best_bio...

# %%
# drop biomarker_id column
df.drop(columns = ['biomarker_id'], inplace = True)

# rename tmp_id column to biomarker_id
df.rename(columns = {'tmp_id': 'biomarker_id'}, inplace = True)
df.head()
# Out:
#    biomarker_id            biomarker assessed_biomarker_entity_id  \
# 0           307  increased IL6 level                  UPKB:P05231
# 1           297  increased IL6 level                  UPKB:P05231
# 2           297  increased IL6 level                  UPKB:P05231
# 3           297  increased IL6 level                  UPKB:P05231
# 4           297  increased IL6 level                  UPKB:P05231
#
#   assessed_biomarker_entity assessed_entity_type best_biomarker_role specimen  \
# 0             Interleukin-6              protein          prognostic    blood
# 1             Interleukin-6              protein          monitoring    blood
# 2             Interleukin-6              protein          monitoring    blood
# 3             Interleukin-6              protein          monitoring    blood
# 4             Interleukin-6              protein          monitoring    blood
#
#       specimen_id loinc_code        condition  condition_id  evidence_source  \
# 0  UBERON:0000178    26881-3  prostate cancer    DOID:10283  PubMed:10914713
# 1  UBERON:0000178    26881-3         COVID-19  DOID:0080600  PubMed:32259560
# 2  UBERON:0000178    26881-3         COVID-19  DOID:0080600  PubMed:32428990
# 3  UBERON:0000178    26881-3         COVID-19  DOID:0080600  PubMed:32677844
# 4  UBERON:0000178    26881-3         COVID-19  DOID:0080600  PubMed:32438331
#
#                                             evidence  \
# 0  Univariate analysis of all patients demonstrat...
# 1  Serial measurement of circulating IL-6 levels ...
# 2  The decrease of IL-6 was closely related to tr...
# 3  Elevated levels of IL-6, D-dimer, CRP, LDH, an...
# 4  Clinical biomarkers for chronic inflammation, ...
#
#                                                 tags
# 0  biomarker; assessed_biomarker_entity; best_bio...
# 1  biomarker; assessed_biomarker_entity; best_bio...
# 2  biomarker; assessed_biomarker_entity; best_bio...
# 3  biomarker; assessed_biomarker_entity; best_bio...
# 4  biomarker; assessed_biomarker_entity; best_bio...

# %%
df.value_counts('biomarker_id')
# Out:
# biomarker_id
# 203    27
# 297    15
# 59     15
# 224    13
# 326     8
#        ..
# 533     1
# 534     1
# 535     1
# 536     1
# 537     1
# Name: count, Length: 549, dtype: int64

# %%
# rename tags column to tag 
df.rename(columns = {'tags': 'tag'}, inplace = True)
df.head()
# Out:
#    biomarker_id            biomarker assessed_biomarker_entity_id  \
# 0           307  increased IL6 level                  UPKB:P05231
# 1           297  increased IL6 level                  UPKB:P05231
# 2           297  increased IL6 level                  UPKB:P05231
# 3           297  increased IL6 level                  UPKB:P05231
# 4           297  increased IL6 level                  UPKB:P05231
#
#   assessed_biomarker_entity assessed_entity_type best_biomarker_role specimen  \
# 0             Interleukin-6              protein          prognostic    blood
# 1             Interleukin-6              protein          monitoring    blood
# 2             Interleukin-6              protein          monitoring    blood
# 3             Interleukin-6              protein          monitoring    blood
# 4             Interleukin-6              protein          monitoring    blood
#
#       specimen_id loinc_code        condition  condition_id  evidence_source  \
# 0  UBERON:0000178    26881-3  prostate cancer    DOID:10283  PubMed:10914713
# 1  UBERON:0000178    26881-3         COVID-19  DOID:0080600  PubMed:32259560
# 2  UBERON:0000178    26881-3         COVID-19  DOID:0080600  PubMed:32428990
# 3  UBERON:0000178    26881-3         COVID-19  DOID:0080600  PubMed:32677844
# 4  UBERON:0000178    26881-3         COVID-19  DOID:0080600  PubMed:32438331
#
#                                             evidence  \
# 0  Univariate analysis of all patients demonstrat...
# 1  Serial measurement of circulating IL-6 levels ...
# 2  The decrease of IL-6 was closely related to tr...
# 3  Elevated levels of IL-6, D-dimer, CRP, LDH, an...
# 4  Clinical biomarkers for chronic inflammation, ...
#
#                                                  tag
# 0  biomarker; assessed_biomarker_entity; best_bio...
# 1  biomarker; assessed_biomarker_entity; best_bio...
# 2  biomarker; assessed_biomarker_entity; best_bio...
# 3  biomarker; assessed_biomarker_entity; best_bio...
# 4  biomarker; assessed_biomarker_entity; best_bio...

# %%
# strip internal whitespace
df['tag'] = df['tag'].str.replace(' ', '')

# %%
# write tsv 
df.to_csv('../data/results/tables/oncomx.tsv', sep='\t', index=False)
